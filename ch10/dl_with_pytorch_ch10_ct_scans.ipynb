# %% [markdown]
# # Classification of Nodules in CT Scans
# This is the first notebook about the classification of nodules in CT scans. A CT scan is a 3D dataset that contains an indexed collection of images in which each image represent a slice of a body of part of it. The complete data is divided in 10 subsets and each subset contains a set of CT scans. The data format used for the CT scan is DICOM. Each subset contains 90 CT scans. Each CT scan is composed of the raw data (file name extension .raw) and its metadata (file name extension .mhd). The raw data contains the value of the density of the body tissues within each 3D volume element (voxel) in [Hounsfield units](https://en.wikipedia.org/wiki/Hounsfield_scale). The size of a voxel is about 1.125 mm × 1.125 mm × 2.5 mm. A CT scan contains about 100 slices along the z direction and each slice is an image of 512 rows x 512 columns. The metadata file contains information about nodules, voxels that may contain benign or malignant cells. The purpose of the project is to build a neural network model to classify such nodules. We use some annotation data to build the examples to be used for training and validation. The examples are not provided in a format that can be used as input to the model so they have to be built using the annotation data provided as csv files with the coordinates of the voxel and their classification as described in the following sections of this notebook.
#
# ## Data loading
# We need data to train our model. Most of the time the raw data does not come in a format suitable for training, it must be transformed in some ways. In this notebook we will address this topic. The datasets that will be used, the LUNA16 datasets, are available online.
#
# ## LUNA16 datasets
# The data is split in several files to be downloaded from Zenodo
# [Luna16 - Part 1/2](https://zenodo.org/record/3723295) (7 zip files)
# [Luna16 - Part 2/2](https://zenodo.org/record/2596479) (3 zip files)
#
# If there's not enough space available the examples can be run with only one or two subsets. The model will not perform well as with the full dataset but it will be possible to run it (see note on ch.10, pag.252). Other datasets, candidates.csv and annotations.csv, are available from the DLWPT book repository in the data/part2/luna/ folder.

# %%
# !git clone https://github.com/deep-learning-with-pytorch/dlwpt-code.git
# Out:
# Cloning into 'dlwpt-code'...
# remote: Enumerating objects: 703, done.
# remote: Total 703 (delta 0), reused 0 (delta 0), pack-reused 703
# Receiving objects: 100% (703/703), 176.00 MiB | 26.05 MiB/s, done.
# Resolving deltas: 100% (309/309), done.
# Checking out files: 100% (228/228), done.

# %%
cd dlwpt-code/
# Out:
# /content/dlwpt-code

# %%
mkdir data-unversioned

# %%
cd data-unversioned
# Out:
# /content/dlwpt-code/data-unversioned

# %%
mkdir part2

# %%
cd part2
# Out:
# /content/dlwpt-code/data-unversioned/part2

# %%
mkdir luna

# %%
cd luna
# Out:
# /content/dlwpt-code/data-unversioned/part2/luna

# %% [markdown]
# We download subset0 of part 1/2 of the data. Each subset contains about 90 CT scan raw datasets. Each CT scan file name is defined by its unique identifier and the .raw extension.

# %%
# !wget https://zenodo.org/record/3723295/files/subset0.zip
#!wget https://zenodo.org/record/3723295/files/subset1.zip
#!wget https://zenodo.org/record/3723295/files/subset2.zip
#!wget https://zenodo.org/record/3723295/files/subset3.zip
#!wget https://zenodo.org/record/3723295/files/subset4.zip
#!wget https://zenodo.org/record/3723295/files/subset5.zip
#!wget https://zenodo.org/record/3723295/files/subset6.zip
# Out:
# --2022-11-21 13:33:33--  https://zenodo.org/record/3723295/files/subset0.zip
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6811924508 (6.3G) [application/octet-stream]
# Saving to: ‘subset0.zip.1’
#
# subset0.zip.1       100%[===================>]   6.34G  11.9MB/s    in 26m 18s
#
# 2022-11-21 13:59:52 (4.12 MB/s) - ‘subset0.zip.1’ saved [6811924508/6811924508]

# %% [markdown]
# We can download subset7 0f the 2nd part of the dataset

# %%
#!wget https://zenodo.org/record/2596479/files/subset7.zip
#!wget https://zenodo.org/record/2596479/files/subset8.zip
#!wget https://zenodo.org/record/2596479/files/subset9.zip

# %% [markdown]
# We unzip the first subset

# %%
!7z x subset0.zip
#!7z x subset7.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 2520087554 bytes (2404 MiB)
#
# Extracting archive: subset0.zip
#
# ERRORS:
# Unexpected end of archive
#
# --
# Path = subset0.zip
# Type = zip
# ERRORS:
# Unexpected end of archive
# Physical Size = 2552146624
#
# ERROR: Data Error : subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223.raw
# 100% 63 - subset0/1.3.6.1.4.1.14519.5.2 . 62600322799211676960828223.raw
# Sub items Errors: 1
#
# Archives with Errors: 1
#
# Open Errors: 1
#
# Sub items Errors: 1

# %%
cd subset0/
# Out:
# /content/dlwpt-code/data-unversioned/part2/luna/subset0

# %%
ls -alh
# Out:
# total 4.0G
# drwx------ 2 root root  12K Nov 21 14:07 ./
# drwxr-xr-x 3 root root 4.0K Nov 21 14:06 ../
# -rw-r--r-- 1 root root  428 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.mhd
# -rw-r--r-- 1 root root  61M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.raw
# -rw-r--r-- 1 root root  411 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.mhd
# -rw-r--r-- 1 root root  60M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.raw
# -rw-r--r-- 1 root root  423 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.mhd
# -rw-r--r-- 1 root root  81M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.raw
# -rw-r--r-- 1 root root  453 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987.mhd
# -rw-r--r-- 1 root root 269M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987.raw
# -rw-r--r-- 1 root root  440 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.122763913896761494371822656720.mhd
# -rw-r--r-- 1 root root  62M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.122763913896761494371822656720.raw
# -rw-r--r-- 1 root root  440 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565.mhd
# -rw-r--r-- 1 root root  98M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565.raw
# -rw-r--r-- 1 root root  423 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.126121460017257137098781143514.mhd
# -rw-r--r-- 1 root root  67M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.126121460017257137098781143514.raw
# -rw-r--r-- 1 root root  416 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354.mhd
# -rw-r--r-- 1 root root 336M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354.raw
# -rw-r--r-- 1 root root  421 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912.mhd
# -rw-r--r-- 1 root root  67M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912.raw
# -rw-r--r-- 1 root root  433 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950.mhd
# -rw-r--r-- 1 root root 242M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950.raw
# -rw-r--r-- 1 root root  446 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.130438550890816550994739120843.mhd
# -rw-r--r-- 1 root root 137M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.130438550890816550994739120843.raw
# -rw-r--r-- 1 root root  405 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441.mhd
# -rw-r--r-- 1 root root  99M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441.raw
# -rw-r--r-- 1 root root  418 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097.mhd
# -rw-r--r-- 1 root root 123M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097.raw
# -rw-r--r-- 1 root root  393 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.138080888843357047811238713686.mhd
# -rw-r--r-- 1 root root 148M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.138080888843357047811238713686.raw
# -rw-r--r-- 1 root root  414 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.139258777898746693365877042411.mhd
# -rw-r--r-- 1 root root 294M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.139258777898746693365877042411.raw
# -rw-r--r-- 1 root root  421 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.139713436241461669335487719526.mhd
# -rw-r--r-- 1 root root  70M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.139713436241461669335487719526.raw
# -rw-r--r-- 1 root root  426 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.141069661700670042960678408762.mhd
# -rw-r--r-- 1 root root 140M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.141069661700670042960678408762.raw
# -rw-r--r-- 1 root root  449 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.144438612068946916340281098509.mhd
# -rw-r--r-- 1 root root  79M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.144438612068946916340281098509.raw
# -rw-r--r-- 1 root root  446 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.146429221666426688999739595820.mhd
# -rw-r--r-- 1 root root 365M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.146429221666426688999739595820.raw
# -rw-r--r-- 1 root root  396 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227.mhd
# -rw-r--r-- 1 root root 138M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227.raw
# -rw-r--r-- 1 root root  419 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748.mhd
# -rw-r--r-- 1 root root  63M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748.raw
# -rw-r--r-- 1 root root  439 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493.mhd
# -rw-r--r-- 1 root root  74M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493.raw
# -rw-r--r-- 1 root root  396 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952.mhd
# -rw-r--r-- 1 root root 123M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952.raw
# -rw-r--r-- 1 root root  436 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.194440094986948071643661798326.mhd
# -rw-r--r-- 1 root root  98M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.194440094986948071643661798326.raw
# -rw-r--r-- 1 root root  427 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.194465340552956447447896167830.mhd
# -rw-r--r-- 1 root root  65M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.194465340552956447447896167830.raw
# -rw-r--r-- 1 root root  415 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196.mhd
# -rw-r--r-- 1 root root  67M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196.raw
# -rw-r--r-- 1 root root  450 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.210837812047373739447725050963.mhd
# -rw-r--r-- 1 root root  97M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.210837812047373739447725050963.raw
# -rw-r--r-- 1 root root  430 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074.mhd
# -rw-r--r-- 1 root root 138M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074.raw
# -rw-r--r-- 1 root root  446 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517.mhd
# -rw-r--r-- 1 root root 125M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517.raw
# -rw-r--r-- 1 root root  401 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729.mhd
# -rw-r--r-- 1 root root 140M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729.raw
# -rw-r--r-- 1 root root  395 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179.mhd
# -rw-r--r-- 1 root root  71M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179.raw
# -rw-r--r-- 1 root root  465 May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223.mhd
# -rw-r--r-- 1 root root  43M May 13  2015 1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223.raw

# %% [markdown]
# The file names follow the Digital Imaging and Communication in Medicine(DICOM) standard. There are two types of files in each subset: files than contains metadata with the filename extension .mhd, and the .raw files that contain the raw data. The raw data in each subset contains about 90 CT scans. We have to transform each pair of .mhd and .raw files into a 3D array.

# %% [markdown]
# ## Label data
# The labels of the data are made available as .csv files in the data/part2/luna/ folder. The candidate.csv file contains the coordinates of the cells that contain lumps that might be classified as a nodule. Each line contains the coordinates of the cell and a final field with info about whether it's a benign (0) or a malignant (1) nodule.

# %%
cd /content/dlwpt-code/data/part2/luna/
# Out:
# /content/dlwpt-code/data/part2/luna

# %%
# !wc -l candidates.csv
# Out:
# 551066 candidates.csv

# %% [markdown]
# We can count how many of those candidates (nodule) are malignant

# %%
# !grep ',1$' candidates.csv | wc -l
# Out:
# 1351

# %% [markdown]
# The annotations.csv file contains additional information about the nodules: the coordinates and the diameter of the nodule. We can count the number of nodules with the annotations simpy by counting the number of lines

# %%
# !wc -l annotations.csv
# Out:
# 1187 annotations.csv

# %% [markdown]
# ## Training and validation sets
# We have to split our dataset into a training set and a validation set. We want both datasets to represent the variability of the real world. We assume that our dataset is a representative sample of the real world. We sort the annotation.csv file by the diameter of the nodule and take one every N line to be moved to the validation set. Unfortunately the coordinates of the center of the nodules in the candidates.csv file and in the annotation.csv file are not exactly the same so we have to line up the coordinates in the two datasets.

# %%
# !grep 100225287222365663678666836860 annotations.csv
# Out:
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860,-128.6994211,-175.3192718,-298.3875064,5.651470635
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860,103.7836509,-211.9251487,-227.12125,4.224708481

# %%
# !grep '100225287222365663678666836860.*,1$' candidates.csv
# Out:
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860,104.16480444,-211.685591018,-227.011363746,1
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860,-128.94,-175.04,-297.87,1

# %%
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## Unifying the label data
# We need to install a couple of packages that are used to preprocess the label data and merge the information from the annotation files, candidates.csv and annotations.csv, the raw data and the metadata. We have to
#
# 1. Use the subsets that we can process given the resources (hard disk space and memory) at our disposal
# 2. Check whether the center of a candidate nodule in cantidates.csv and the nodule in annotations.csv, with the same uid, are close enough to belong to the same nodule
# 3. Put all the information in one single dataset: coordinates, class (benign or malignant), diameter
#
# For the 2nd step we install the [SimpleITK](https://simpleitk.org/) library, a tool for image registration, segmentation and analysis, to compute the coordinates of the center of the nodules and check whether they are close enough.
# We use the [DiskCache](https://pypi.org/project/diskcache/0.7.0/) to handle files in memory

# %%
# !pip install SimpleITK
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SimpleITK
#   Downloading SimpleITK-2.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.8 MB)
#      |████████████████████████████████| 52.8 MB 133 kB/s
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.2.0

# %%
# !pip install "diskcache==4.1.0"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diskcache==4.1.0
#   Downloading diskcache-4.1.0-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 1.1 MB/s
# Installing collected packages: diskcache
# Successfully installed diskcache-4.1.0

# %%
cd /content/dlwpt-code/
# Out:
# /content/dlwpt-code

# %% [markdown]
# Since we want to be able to train the model using only one or two subsets we have to build a dataset with the raw data we have. We import some functions that are defined in the Python script in the folder p2ch10.

# %%
from p2ch10.dsets import getCandidateInfoList, getCt, LunaDataset
candidateInfo_list = getCandidateInfoList(requireOnDisk_bool=True)
positiveInfo_list = [x for x in candidateInfo_list if x[0]]
diameter_list = [x[1] for x in positiveInfo_list]

# %%
print(len(positiveInfo_list))
print(positiveInfo_list[0])
# Out:
# 45
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.7832325, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-82.79150362, -21.43587141, -97.18427459))

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4}  {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0  18.8 mm

# %%
for candidateInfo_tup in positiveInfo_list[:10]:
    print(candidateInfo_tup)
for candidateInfo_tup in positiveInfo_list[-10:]:
    print(candidateInfo_tup)
    
for candidateInfo_tup in positiveInfo_list:
    if candidateInfo_tup.series_uid.endswith('565'):
        print(candidateInfo_tup)
# Out:
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.7832325, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-82.79150362, -21.43587141, -97.18427459))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.75323185, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.1132711884, -15.8936132585, -202.847228297))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-78.2266125547, 180.542140994, -467.88476912))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-82.01161135, 186.5539408, -467.9168457))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.52596027, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223', center_xyz=(75.0930413723, -0.51240559114, -58.1161965725))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.48525426, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-57.04638761, 131.2249427, -520.247305))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.96263215, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(53.8710070042, 139.156354144, -625.795207073))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.84883567, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179', center_xyz=(119.314454061, 19.1701643762, -155.143581615))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.59647134, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(46.00314143, 47.66525294, -108.4822128))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.05335657, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(65.9819404529, 65.3748482043, -245.07371322))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-85.8668496571, -26.6501938805, -95.2879167459))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-86.9514169487, 162.142965995, -455.060669104))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493', center_xyz=(-80.7, 58.42, -131.12))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.8682494235, -22.4152582646, -208.030982511))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-52.48, 135.05, -521.24))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-74.74, 188.44, -468.48))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-81.05, 190.54, -462.17))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(44.25, 52.17, -110.25))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(36.54, 78.1, -122.92))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))

# %%
np.histogram(diameter_list)
# Out:
# (array([12,  1,  5,  9,  4,  4,  1,  3,  1,  5]),
#  array([ 0.        ,  1.87832325,  3.7566465 ,  5.63496975,  7.513293  ,
#          9.39161625, 11.2699395 , 13.14826275, 15.026586  , 16.90490925,
#         18.7832325 ]))

# %%
from p2ch10.vis import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2022-11-21 14:15:26,500 INFO     pid:77 p2ch10.dsets:173:__init__ <p2ch10.dsets.LunaDataset object at 0x7f3efca778d0>: 19465 training samples
# 0 CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.7832325, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-82.79150362, -21.43587141, -97.18427459))
# 1 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.75323185, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.1132711884, -15.8936132585, -202.847228297))
# 2 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-78.2266125547, 180.542140994, -467.88476912))
# 3 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-82.01161135, 186.5539408, -467.9168457))
# 4 CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.52596027, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223', center_xyz=(75.0930413723, -0.51240559114, -58.1161965725))
# 5 CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.48525426, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-57.04638761, 131.2249427, -520.247305))
# 6 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.96263215, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(53.8710070042, 139.156354144, -625.795207073))
# 7 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.84883567, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179', center_xyz=(119.314454061, 19.1701643762, -155.143581615))
# 8 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.59647134, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(46.00314143, 47.66525294, -108.4822128))
# 9 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.05335657, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(65.9819404529, 65.3748482043, -245.07371322))
# 10 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.13983165, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-102.748428579, 154.846550311, -465.913693912))
# 11 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.10051888, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729', center_xyz=(-64.88987189, 196.9697692, -469.20840415))
# 12 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.93827513, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-55.911605232, 175.416751344, -405.328583147))
# 13 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.4626083, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912', center_xyz=(34.1223242148, 87.8273440723, -100.189149775))
# 14 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.25825997, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-86.23791683, 16.037327905, -70.24667756))
# 15 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.982986958, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.194440094986948071643661798326', center_xyz=(56.38967842, -92.71316409, -275.8592896))
# 16 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.621579517, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.139258777898746693365877042411', center_xyz=(-106.98605025, -177.74552385, -192.46801265))
# 17 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.888814398, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-69.3825, 56.288020835, -81.68967418))
# 18 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.053719722, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-84.3086034783, -42.2047464888, -146.649587983))
# 19 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.800248866, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950', center_xyz=(-95.430332199, -87.6984598229, 1131.88013133))
# 20 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.779556482, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(99.534526984, -25.0008193614, -199.759483337))
# 21 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.720277435, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354', center_xyz=(59.73, -157.0, -119.49))
# 22 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.673547135, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179', center_xyz=(99.3146639166, 66.0098225079, -90.5268699307))
# 23 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.440878725, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492', center_xyz=(-100.46, 68.01, -230.55))
# 24 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.401625027, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(108.778555324, 229.013231915, -721.207828036))
# 25 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.305539247, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(79.21, 210.52, -464.74))
# 26 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.259551508, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.141069661700670042960678408762', center_xyz=(-102.01, 248.56, -739.43))
# 27 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.357746933, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-100.11, 179.7, -498.43))
# 28 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.05940652, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.130438550890816550994739120843', center_xyz=(88.4711209658, 32.9338043994, -78.2315830223))
# 29 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.813145858, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729', center_xyz=(-61.1318931033, 224.376802237, -633.722209393))
# 30 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.784886899, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(96.5080202269, 213.298021661, -613.21058414))
# 31 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.681381581, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987', center_xyz=(136.31, 116.67, -181.89))
# 32 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.661014906, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517', center_xyz=(-86.81, -17.42, -51.97))
# 33 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223', center_xyz=(77.1171358377, -6.7515977048, -53.8551263442))
# 34 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517', center_xyz=(-88.91, -4.8, -80.76))
# 35 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-85.8668496571, -26.6501938805, -95.2879167459))
# 36 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-86.9514169487, 162.142965995, -455.060669104))
# 37 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493', center_xyz=(-80.7, 58.42, -131.12))
# 38 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.8682494235, -22.4152582646, -208.030982511))
# 39 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-52.48, 135.05, -521.24))
# 40 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-74.74, 188.44, -468.48))
# 41 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-81.05, 190.54, -462.17))
# 42 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))
# 43 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(44.25, 52.17, -110.25))
# 44 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(36.54, 78.1, -122.92))

# %%
positiveSample_list
# Out:
# [CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.7832325, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-82.79150362, -21.43587141, -97.18427459)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.75323185, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.1132711884, -15.8936132585, -202.847228297)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-78.2266125547, 180.542140994, -467.88476912)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.69382414, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-82.01161135, 186.5539408, -467.9168457)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=17.52596027, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223', center_xyz=(75.0930413723, -0.51240559114, -58.1161965725)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.48525426, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-57.04638761, 131.2249427, -520.247305)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.96263215, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(53.8710070042, 139.156354144, -625.795207073)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.84883567, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179', center_xyz=(119.314454061, 19.1701643762, -155.143581615)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.59647134, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(46.00314143, 47.66525294, -108.4822128)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.05335657, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(65.9819404529, 65.3748482043, -245.07371322)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.13983165, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-102.748428579, 154.846550311, -465.913693912)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.10051888, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729', center_xyz=(-64.88987189, 196.9697692, -469.20840415)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.93827513, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-55.911605232, 175.416751344, -405.328583147)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.4626083, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.128023902651233986592378348912', center_xyz=(34.1223242148, 87.8273440723, -100.189149775)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.25825997, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-86.23791683, 16.037327905, -70.24667756)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.982986958, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.194440094986948071643661798326', center_xyz=(56.38967842, -92.71316409, -275.8592896)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.621579517, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.139258777898746693365877042411', center_xyz=(-106.98605025, -177.74552385, -192.46801265)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.888814398, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-69.3825, 56.288020835, -81.68967418)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.053719722, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(-84.3086034783, -42.2047464888, -146.649587983)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.800248866, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950', center_xyz=(-95.430332199, -87.6984598229, 1131.88013133)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.779556482, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.134996872583497382954024478441', center_xyz=(99.534526984, -25.0008193614, -199.759483337)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.720277435, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354', center_xyz=(59.73, -157.0, -119.49)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.673547135, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219909753224298157409438012179', center_xyz=(99.3146639166, 66.0098225079, -90.5268699307)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.440878725, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492', center_xyz=(-100.46, 68.01, -230.55)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.401625027, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(108.778555324, 229.013231915, -721.207828036)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.305539247, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(79.21, 210.52, -464.74)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.259551508, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.141069661700670042960678408762', center_xyz=(-102.01, 248.56, -739.43)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.357746933, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-100.11, 179.7, -498.43)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.05940652, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.130438550890816550994739120843', center_xyz=(88.4711209658, 32.9338043994, -78.2315830223)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.813145858, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729', center_xyz=(-61.1318931033, 224.376802237, -633.722209393)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.784886899, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.213140617640021803112060161074', center_xyz=(96.5080202269, 213.298021661, -613.21058414)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.681381581, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987', center_xyz=(136.31, 116.67, -181.89)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.661014906, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517', center_xyz=(-86.81, -17.42, -51.97)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.227962600322799211676960828223', center_xyz=(77.1171358377, -6.7515977048, -53.8551263442)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517', center_xyz=(-88.91, -4.8, -80.76)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196', center_xyz=(-85.8668496571, -26.6501938805, -95.2879167459)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188376349804761988217597754952', center_xyz=(-86.9514169487, 162.142965995, -455.060669104)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188209889686363159853715266493', center_xyz=(-80.7, 58.42, -131.12)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.8682494235, -22.4152582646, -208.030982511)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.154677396354641150280013275227', center_xyz=(-52.48, 135.05, -521.24)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-74.74, 188.44, -468.48)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-81.05, 190.54, -462.17)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(44.25, 52.17, -110.25)),
#  CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059', center_xyz=(36.54, 78.1, -122.92))]

# %%
series_uid = positiveSample_list[11][2]
showCandidate(series_uid)
# Out:
# 2022-11-21 14:15:46,249 INFO     pid:77 p2ch10.dsets:173:__init__ <p2ch10.dsets.LunaDataset object at 0x7f3ef573a590>: 764 training samples
# <div id='1e344f1f-fffb-46a1-9ab0-1dfbdc50532c'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.219087313261026510628926082729 0 False [0, 1]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565'
showCandidate(series_uid)
# Out:
# 2022-11-21 14:15:53,100 INFO     pid:77 p2ch10.dsets:173:__init__ <p2ch10.dsets.LunaDataset object at 0x7f3ef61acc90>: 1061 training samples
# <div id='66dcaaa2-9099-4a72-b267-aa66bf2915f4'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565 0 False [0]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
showCandidate(series_uid)
# Out:
# 2022-11-21 14:15:59,664 INFO     pid:77 p2ch10.dsets:173:__init__ <p2ch10.dsets.LunaDataset object at 0x7f3efc783fd0>: 605 training samples
# <div id='93ac3409-7d09-4a0e-96fa-aaf261320b9f'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354 0 False [0]

# %% [markdown]
# ## Coordinates transformation and candidate extraction
# In the raw data the voxel coordinates are refered to an origin in the body, available in the metadata, as distances (x, y, z) in mm. In order to use the data in a neural network model we need to transform the coordinates in to (I, R, C) or index, row, and column. Another pre-processing task is to extract a volume around each candidate nodule to be used for the training and validation task without using the entire dataset. These volumes are composed of 32 slices of images of size 48x48 pixels. The two tasks are performed by the function defined in the script dsets.py and used to build the LunaDataset object that is a custom implementation, i.e. a subclass, of the PyTorch Dataset class used to define the input data of a model. The LunaDataset returns a collection of tuples where each tuple contains information about a candidate sample and a tensor with the transformed values using the (I, R, C) reference coordinates.

# %%
tuple_list = LunaDataset()
# Out:
# 2022-11-21 16:43:27,868 INFO     pid:77 p2ch10.dsets:173:__init__ <p2ch10.dsets.LunaDataset object at 0x7f3ef5c1bb10>: 19465 training samples

# %% [markdown]
# We can plot some slices of a candidate volume, out of the 32 available for each of them, as images of size 48x48 pixels

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# The model that we will build uses 3D convolutions and the tensors used as input have 5 dimensions: number of samples N, channels per sample C, depth D, height H, and width W. We choose one sample out of those available in our dataset. In our case (CT scans) there is only one channel per sample. The depth, the number of slices, is 32, height and width are 48 pixels.

# %%
tuple = 1000 # [0, 19464]
tuple_element = 0
batch = 0
candidate_img = tuple_list[tuple][tuple_element][batch]
candidate_img.shape
# Out:
# torch.Size([32, 48, 48])

# %%
slice_index = 0
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(15, 15))
for col in range(0, 4):
  ax[0, col].imshow(candidate_img[slice_index], cmap='gray')
  ax[1, col].imshow(candidate_img[slice_index + 4], cmap='gray')
  slice_index += 1
